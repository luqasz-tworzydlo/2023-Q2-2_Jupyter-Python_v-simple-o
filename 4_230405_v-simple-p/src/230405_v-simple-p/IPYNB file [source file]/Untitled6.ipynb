# %%
# importowanie funkcji ze zbioru modułów

# %%
from moduly.Figury3d import pole_kwadratu

# %%
a = pole_kwadratu(5)
print(a)
# Out:
# 25

# %%
# operacje na modułach [pliku sinus.py oraz Figury3d.py],
# jak i również wykonywanie działań z użyciem pliku csv [nba.csv]

# %%
import moduly.sinus as sn

# %%
b = sn.sin(5)

# %%
print(b)
# Out:
# -0.9589242746631385

# %%
import moduly.Figury3d as fig

# %%
c = fig.pole_kwadratu(5)

# %%
print(c)
# Out:
# 25

# %%
import pandas as pd

# %%
df = pd.read_csv('nba.csv')

# %%
nba = df.copy()

# %%
nba.tail(15)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 443      Trey Burke  Utah Jazz     3.0       PG  23.0    6-1   191.0
# 444      Alec Burks  Utah Jazz    10.0       SG  24.0    6-6   214.0
# 445      Dante Exum  Utah Jazz    11.0       PG  20.0    6-6   190.0
# 446  Derrick Favors  Utah Jazz    15.0       PF  24.0   6-10   265.0
# 447     Rudy Gobert  Utah Jazz    27.0        C  23.0    7-1   245.0
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 450      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454       Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# ...

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba[['Name']].head(7)
# Out:
#             Name
# 0  Avery Bradley
# 1    Jae Crowder
# 2   John Holland
# 3    R.J. Hunter
# 4  Jonas Jerebko
# 5   Amir Johnson
# 6  Jordan Mickey

# %%
nba[['Name','Salary','Number']].head(7)
# Out:
#             Name      Salary  Number
# 0  Avery Bradley   7730337.0     0.0
# 1    Jae Crowder   6796117.0    99.0
# 2   John Holland         NaN    30.0
# 3    R.J. Hunter   1148640.0    28.0
# 4  Jonas Jerebko   5000000.0     8.0
# 5   Amir Johnson  12000000.0    90.0
# 6  Jordan Mickey   1170960.0    55.0

# %%
nba['Sport']='Basketball'

# %%
nba.insert(3,column='League', value='National Basketball Association')

# %%
nba.head()
# Out:
#             Name            Team  Number                           League  \
# 0  Avery Bradley  Boston Celtics     0.0  National Basketball Association
# 1    Jae Crowder  Boston Celtics    99.0  National Basketball Association
# 2   John Holland  Boston Celtics    30.0  National Basketball Association
# 3    R.J. Hunter  Boston Celtics    28.0  National Basketball Association
# 4  Jonas Jerebko  Boston Celtics     8.0  National Basketball Association
#
#   Position   Age Height  Weight            College     Salary       Sport
# 0       PG  25.0    6-2   180.0              Texas  7730337.0  Basketball
# 1       SF  25.0    6-6   235.0          Marquette  6796117.0  Basketball
# 2       SG  27.0    6-5   205.0  Boston University        NaN  Basketball
# 3       SG  22.0    6-5   185.0      Georgia State  1148640.0  Basketball
# 4       PF  29.0   6-10   231.0                NaN  5000000.0  Basketball

# %%
nba['Waga w kg']= nba['Weight']*0.535

# %%
nba.head()
# Out:
#             Name            Team  Number                           League  \
# 0  Avery Bradley  Boston Celtics     0.0  National Basketball Association
# 1    Jae Crowder  Boston Celtics    99.0  National Basketball Association
# 2   John Holland  Boston Celtics    30.0  National Basketball Association
# 3    R.J. Hunter  Boston Celtics    28.0  National Basketball Association
# 4  Jonas Jerebko  Boston Celtics     8.0  National Basketball Association
#
#   Position   Age Height  Weight            College     Salary       Sport  \
# 0       PG  25.0    6-2   180.0              Texas  7730337.0  Basketball
# 1       SF  25.0    6-6   235.0          Marquette  6796117.0  Basketball
# 2       SG  27.0    6-5   205.0  Boston University        NaN  Basketball
# 3       SG  22.0    6-5   185.0      Georgia State  1148640.0  Basketball
# 4       PF  29.0   6-10   231.0                NaN  5000000.0  Basketball
#
#    Waga w kg
# 0     96.300
# 1    125.725
# 2    109.675
# 3     98.975
# ...

# %%
nba['Pensja w mln'] = round(nba['Salary']/1000000,2)

# %%
nba.head()
# Out:
#             Name            Team  Number                           League  \
# 0  Avery Bradley  Boston Celtics     0.0  National Basketball Association
# 1    Jae Crowder  Boston Celtics    99.0  National Basketball Association
# 2   John Holland  Boston Celtics    30.0  National Basketball Association
# 3    R.J. Hunter  Boston Celtics    28.0  National Basketball Association
# 4  Jonas Jerebko  Boston Celtics     8.0  National Basketball Association
#
#   Position   Age Height  Weight            College     Salary       Sport  \
# 0       PG  25.0    6-2   180.0              Texas  7730337.0  Basketball
# 1       SF  25.0    6-6   235.0          Marquette  6796117.0  Basketball
# 2       SG  27.0    6-5   205.0  Boston University        NaN  Basketball
# 3       SG  22.0    6-5   185.0      Georgia State  1148640.0  Basketball
# 4       PF  29.0   6-10   231.0                NaN  5000000.0  Basketball
#
#    Waga w kg  Pensja w mln
# 0     96.300          7.73
# ...

# %%
nba['Pensja w mln'].value_counts()
# Out:
# 0.95     32
# 0.85     18
# 0.53     13
# 16.41     6
# 1.10      6
#          ..
# 0.60      1
# 13.91     1
# 10.30     1
# 17.12     1
# 0.90      1
# Name: Pensja w mln, Length: 273, dtype: int64

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df1 = df1['College'].fillna('WSB Merito University')

# %%
df1.head()
# Out:
# 0                    Texas
# 1                Marquette
# 2        Boston University
# 3            Georgia State
# 4    WSB Merito University
# Name: College, dtype: object

# %%
df1
# Out:
# 0                      Texas
# 1                  Marquette
# 2          Boston University
# 3              Georgia State
# 4      WSB Merito University
#                ...
# 453                   Butler
# 454    WSB Merito University
# 455    WSB Merito University
# 456                   Kansas
# 457    WSB Merito University
# Name: College, Length: 458, dtype: object

# %%
df1.fillna('WSB')
# Out:
# 0                      Texas
# 1                  Marquette
# 2          Boston University
# 3              Georgia State
# 4      WSB Merito University
#                ...
# 453                   Butler
# 454    WSB Merito University
# 455    WSB Merito University
# 456                   Kansas
# 457    WSB Merito University
# Name: College, Length: 458, dtype: object

# %%
df1.head()
# Out:
# 0                    Texas
# 1                Marquette
# 2        Boston University
# 3            Georgia State
# 4    WSB Merito University
# Name: College, dtype: object

# %%
osoby = {'imie':['Jan','Magda','Kasia'],
        'wiek':[55,20,33]}

# %%
osoby
# Out:
# {'imie': ['Jan', 'Magda', 'Kasia'], 'wiek': [55, 20, 33]}

# %%
df = pd.DataFrame(osoby)

# %%
df
# Out:
#     imie  wiek
# 0    Jan    55
# 1  Magda    20
# 2  Kasia    33

# %%
print(df.loc[[0,1]])
# Out:
#     imie  wiek
# 0    Jan    55
# 1  Magda    20

# %%
nba.loc[:10]
# Out:
#                Name            Team  Number                           League  \
# 0     Avery Bradley  Boston Celtics     0.0  National Basketball Association
# 1       Jae Crowder  Boston Celtics    99.0  National Basketball Association
# 2      John Holland  Boston Celtics    30.0  National Basketball Association
# 3       R.J. Hunter  Boston Celtics    28.0  National Basketball Association
# 4     Jonas Jerebko  Boston Celtics     8.0  National Basketball Association
# 5      Amir Johnson  Boston Celtics    90.0  National Basketball Association
# 6     Jordan Mickey  Boston Celtics    55.0  National Basketball Association
# 7      Kelly Olynyk  Boston Celtics    41.0  National Basketball Association
# 8      Terry Rozier  Boston Celtics    12.0  National Basketball Association
# 9      Marcus Smart  Boston Celtics    36.0  National Basketball Association
# 10  Jared Sullinger  Boston Celtics     7.0  National Basketball Association
#
# ...

# %%
nba = nba.set_index('Name')

# %%
nba.loc['Kelly Olynyk']
# Out:
# Team                             Boston Celtics
# Number                                     41.0
# League          National Basketball Association
# Position                                      C
# Age                                        25.0
# Height                                      7-0
# Weight                                    238.0
# College                                 Gonzaga
# Salary                                2165160.0
# Sport                                Basketball
# Waga w kg                                127.33
# Pensja w mln                               2.17
# Name: Kelly Olynyk, dtype: object

# %%
nba.iloc[0,10]
# Out:
# 96.30000000000001
